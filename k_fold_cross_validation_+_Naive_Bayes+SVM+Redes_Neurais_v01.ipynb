# %% [markdown]
# <a href="https://colab.research.google.com/github/carlaprv/sin5007-reconhecimento-de-padroes/blob/master/k_fold_cross_validation_%2B_Naive_Bayes%2BSVM%2BRedes_Neurais_v01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the entire repo.
# !git clone -l -s https://github.com/carlaprv/sin5007-reconhecimento-de-padroes cloned-repo
# %cd cloned-repo
# !ls
# Out:
# fatal: destination path 'cloned-repo' already exists and is not an empty directory.
# /content/cloned-repo
# '02 - Normalizacao_dataset_v01.ipynb'
# '02 - Normalizacao_dataset_v02.ipynb'
# '02 - Normalizacao_dataset_v03-portugues.ipynb'
# '03 - PCA_v01.ipynb'
# '03 - PCA_v02-portugues.ipynb'
# '04 - 01 Features Selection - Chi Squared v01.ipynb'
# '04 - 01 Features Selection - Chi Squared v02.ipynb'
# '04 - 02 Features Selection - Recursive Feature Elimination.ipynb'
# '04 - 02 Features Selection - Recursive Feature Elimination v02.ipynb'
# '04 - 03 Features Selection - Feature Importance.ipynb'
# '04 - 03 Features Selection - Feature Importance v02.ipynb'
# '04 - 04 Features Selection - Correlation Matrix.ipynb'
# '04 - 05 Features Selection - Select from Model.ipynb'
# '04 - 06 Features Selection Comparison.ipynb'
# '05 - Function k-fold cross validation-(biblioteca sklearn).ipynb'
# '05 - Function k-fold cross validation.ipynb'
# '06 - k-fold cross validation + naive bayes v01.ipynb'
# '06 - k-fold cross validation + naive Bayes v02.ipynb'
# '06 - k-fold cross validation + naive Bayes v03.ipynb'
# '06 - k-fold cross validation + naive Bayes v04.ipynb'
# '06 - k-fold cross validation + naive Bayes v05.ipynb'
# '07 - Naive Bayes + SVM v01.ipynb'
# '07 - Naive Bayes + SVM v02.ipynb'
# 'data exploring notebooks'
#  dataset
#  graph.png
#  kaggle
#  README.md
#  results

# %% [markdown]
# # Naive Bayes + SVM
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Bibliotecas Necessárias

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
import seaborn as sns # visualize
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms

from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn import metrics
from sklearn.metrics import precision_recall_fscore_support
from statsmodels.stats.weightstats import DescrStatsW
import warnings
from sklearn.model_selection import ParameterGrid
from sklearn.neural_network import MLPClassifier

warnings.filterwarnings('ignore')  # "error", "ignore", "always", "default", "module" or "once"
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Funções Auxiliares
#
# describe_dataset() : realiza o cálculo das proporções de classes do dataset original

# %%
def describe_dataset(X, y, k):
    # get dataset rows: instances , columns: features
    rows, columns = X.shape
    # get proportion from target
    (unique, counts) = np.unique(y, return_counts=True) 
    # calculate proportion
    prop_neg = int(counts[0]/rows*100)
    prop_pos = int(counts[1]/rows*100)

    print("k = {}, Dataset: {} positivas, {} negativas ({}% x {}%)".format(k, counts[1], counts[0], prop_pos, prop_neg))
    print("")

# %% [markdown]
# get_classes_from_index() : realiza o cálculo das proporções de classes dos folds criados

# %%
def get_classes_from_index(y, skf):
    _, y_idx, y_inv = np.unique(y, return_index=True, return_inverse=True)
    y_counts = np.bincount(y_inv)
    _, class_perm = np.unique(y_idx, return_inverse=True)
    y_encoded = class_perm[y_inv]
    y_order = np.sort(y_encoded)
    n_classes = len(y_idx)
    allocation = np.asarray(
            [np.bincount(y_order[i::skf.n_splits], minlength=n_classes)
             for i in range(skf.n_splits)])

    for idx, f in enumerate(allocation):
        count_neg = int(f[0])
        count_pos = int(f[1])
        total = count_neg+count_pos
        prop_temp_neg = int(count_neg/total*100)
        prop_temp_pos = int(count_pos/total*100)
        print("Fold {}: Pos: {}, Neg: {}, Total: {}, Proporção: {}% x {}%".format(idx, count_pos, count_neg, total, prop_temp_pos, prop_temp_neg))
    print("")

# %% [markdown]
# get_ic(): realiza o cálculo do indice de confiança

# %%
def get_ic(data, alpha):
    
    mean_c = []
    for result in lista_result:
        
        c = result[0]
        result_c = result[1]
        
        # Calcula a média das medidas do parametro c
        precision_mean = result_c['precision'].mean()
        recall_mean = result_c['recall'].mean()
        f1_score_mean = result_c['f1-score'].mean()
        support_mean = result_c['support'].mean()
        accuracy_mean = result_c['accuracy'].mean()

        # Calcula as ic das medidas
        precision_ic = sms.DescrStatsW(result_c['precision']).tconfint_mean(alpha)
        recall_ic = sms.DescrStatsW(result_c['recall']).tconfint_mean(alpha)
        f1_score_ic = sms.DescrStatsW(result_c['f1-score']).tconfint_mean(alpha)
        support_ic = sms.DescrStatsW(result_c['support']).tconfint_mean(alpha)
        accuracy_ic = sms.DescrStatsW(result_c['accuracy']).tconfint_mean(alpha)

        ic = {'recall_ic' : recall_ic, 'support_ic' : support_ic, 'accuracy_ic': accuracy_ic }
        ic = pd.DataFrame(ic, index=['inf','sup'])

        # Armazena a média das medidas do parametro c
        mean_c.append([c, precision_mean, recall_mean, f1_score_mean, support_mean, accuracy_mean])
    
    name_columns = ['c', 'precision_mean', 'recall_mean', 'f1_score_mean', 'support_mean', 'accuracy_mean']
    mean_c = pd.DataFrame(mean_c, columns=name_columns)
    return mean_c, ic

# %%
def get_ic(data, alpha):

    # Calcula as ic das medidas
    accuracy_ic_inf, accuracy_ic_sup = sms.DescrStatsW(data['accuracy']).tconfint_mean(alpha)
    precision_ic_inf, precision_ic_sup = sms.DescrStatsW(data['precision']).tconfint_mean(alpha)
    recall_ic_inf, recall_ic_sup = sms.DescrStatsW(data['recall']).tconfint_mean(alpha)
    fscore_ic_inf, fscore_ic_sup = sms.DescrStatsW(data['fscore']).tconfint_mean(alpha)
    
    ic = [accuracy_ic_inf, accuracy_ic_sup, precision_ic_inf, precision_ic_sup, recall_ic_inf, recall_ic_sup, fscore_ic_inf, fscore_ic_sup]

    return ic

# %%
def Classifier_grid(X, y, k, parameters_in , Classifier, dataSet):
     
    """
    Parameters
    ----------    
              X: array-like, shape (n_samples, n_features) -- Training data, where n_samples is the number of samples and n_features is the number of features.
              y: array-like, of length n_samples  -- The target variable for supervised learning problems.
              k: int -- Determines the number of folds.
        dataSet: method selection (string)
  parameters_in: all parameters (tuple)

    """
    ### Estratifica o dataset em k folds
    skf = StratifiedKFold(n_splits=k)
    describe_dataset(X, y, k)
    get_classes_from_index(y, skf) 

    ### ParameterGrid
    list_parameters = ParameterGrid(parameters_in)
       
    #################################################################################################################
    # 1. Classifier 
    #################################################################################################################
    result = []
    result_ic = []
    result_k = []
    result_best = []

    total_p = len(list_parameters)
    print("---")
    print('Quantidade de parametros:', total_p)
    p=1
    for P in list_parameters:
        print('Parametro:',p,'/',total_p)
        print(P)

        ### resultado do fold-k
        clf = Classifier(**P)

        fold_k = 1
        for train_index, test_index in skf.split(X, y):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]

            ### Train the model
            clf.fit(X_train, y_train)
    
            ### Test the model
            y_predicted = clf.predict(X_test)
            
            ### calculate metrics
            report_dict = metrics.classification_report(y_test, y_predicted, output_dict=True)
            report_str = metrics.classification_report(y_test, y_predicted)        
            ### print(report_str)
            
            all_metrics = precision_recall_fscore_support(y_true=y_test, y_pred=y_predicted, average='weighted')
            accuracy = metrics.accuracy_score(y_true=y_test, y_pred=y_predicted)
            precision = all_metrics[0]
            recall = all_metrics[1]
            fscore = all_metrics[2]
                        
            ### Armazena o resultado do fold k
            r = [Classifier.__name__, fold_k, accuracy ,  precision,  recall , fscore] + list(P.values())
            result_k.append(r)
            #print(result_k)
            fold_k = fold_k + 1
            
    
        columns_r = [Classifier.__name__, 'fold', 'accuracy','precision','recall','fscore'] + list(P.keys())
        
        p=p+1
        result_k = pd.DataFrame(result_k, columns=columns_r)

        ### calcula a média das métricas dos k-folds      
        accuracy_avg = result_k['accuracy'].mean()
        precision_avg = result_k['precision'].mean()
        recall_avg = result_k['recall'].mean()
        fscore_avg = result_k['fscore'].mean()
        
        ### Calcula o índice de confiança dos k-folds
        alpha = 0.05
        ic_c = list(get_ic(result_k, alpha))
        
        ### Armazena a média dos resultados dos k-folds e o índice de confiança
        result.append([Classifier.__name__, accuracy_avg, precision_avg, recall_avg, fscore_avg] + list(P.values())) 
        result_ic.append(list(ic_c) + list(P.values()))
        result_k = []

    
    ### Exibe a media dos resultados de cada valor
    columns_avg = [Classifier.__name__, 'accuracy_avg','precision_avg','recall_avg','fscore_avg'] + list(P.keys())
    result = pd.DataFrame(result, columns=columns_avg)

      
    columns_ic = ['accuracy_ic_inf','accuracy_ic_sup','precision_ic_inf','precision_ic_sup','recall_ic_inf', 'recall_ic_sup','fscore_ic_inf', 'fscore_ic_sup'] + list(P.keys())
    result_ic = pd.DataFrame(result_ic, columns=columns_ic)
    #print("Média dos resultados")
    #print(result)
    #print(result_ic)
    #print("")
        
    #################################################################################################################
    ### ARMAZENA OS MELHORES RESULTADOS 
    #################################################################################################################
    
    ### Armazena apenas as métricas da melhor acurácia média do MODELO e o seu indice de confiança
  
    result_best = pd.DataFrame(result.iloc[[result['accuracy_avg'].argmax()]])
    print(result_best)
   
    ic_best = pd.DataFrame(result_ic.iloc[[result['accuracy_avg'].argmax()]])
    print(ic_best)
    
    return result_best, ic_best

# %% [markdown]
# # 1. Naive Bayes

# %% [markdown]
# ##### Parâmetros de execução do Naive Bayes
# * list_c : valores do parâmetro de ajuste de probabilidade
#
# * k_folds : número de folds para a estratificação do dataset

# %%
list_c = [0.001, 0.10, 0.25, 0.50, 0.75, 1]
k_folds = 10

# %% [markdown]
# ### 1.1. Naive Bayes: All Features

# %%
df = pd.read_csv('results/dataset-normalizado.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'var_smoothing': [0.001, 0.10, 0.25, 0.50, 0.75, 1]}

result_NB_all, ic_NB_all = Classifier_grid(X, y, k_folds, parameters_in, GaussianNB, dataSet='All Features')
print("Melhor resultado:")
result_NB_all
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 6
# Parametro: 1 / 6
# {'var_smoothing': 0.001}
# Parametro: 2 / 6
# {'var_smoothing': 0.1}
# Parametro: 3 / 6
# {'var_smoothing': 0.25}
# Parametro: 4 / 6
# {'var_smoothing': 0.5}
# Parametro: 5 / 6
# {'var_smoothing': 0.75}
# Parametro: 6 / 6
# {'var_smoothing': 1}
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 1  GaussianNB       0.71488  ...    0.700049            0.1
#
# [1 rows x 6 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 1         0.647212         0.782547  ...       0.780758            0.1
#
# [1 rows x 9 columns]
# Melhor resultado:
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 1  GaussianNB       0.71488  ...    0.700049            0.1
#
# [1 rows x 6 columns]

# %% [markdown]
# Índice de Confiança do melhor resultado

# %%
ic_NB_all
# Out:
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 1         0.647212         0.782547  ...       0.780758            0.1
#
# [1 rows x 9 columns]

# %% [markdown]
# ### 1.2. Naive Bayes: PCA

# %%
df = pd.read_csv('results/dataset-pca.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'var_smoothing': [0.001, 0.10, 0.25, 0.50, 0.75, 1]}

result_NB_pca, ic_NB_pca = Classifier_grid(X, y, k_folds, parameters_in, GaussianNB, dataSet='PCA')
print("Melhor resultado:")
result_NB_pca
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 6
# Parametro: 1 / 6
# {'var_smoothing': 0.001}
# Parametro: 2 / 6
# {'var_smoothing': 0.1}
# Parametro: 3 / 6
# {'var_smoothing': 0.25}
# Parametro: 4 / 6
# {'var_smoothing': 0.5}
# Parametro: 5 / 6
# {'var_smoothing': 0.75}
# Parametro: 6 / 6
# {'var_smoothing': 1}
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 3  GaussianNB      0.687188  ...    0.650919            0.5
#
# [1 rows x 6 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 3         0.615426         0.758949  ...       0.753306            0.5
#
# [1 rows x 9 columns]
# Melhor resultado:
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 3  GaussianNB      0.687188  ...    0.650919            0.5
#
# [1 rows x 6 columns]

# %% [markdown]
# Índice de Confiança

# %%
ic_NB_pca
# Out:
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 3         0.615426         0.758949  ...       0.753306            0.5
#
# [1 rows x 9 columns]

# %% [markdown]
# ### 1.3. Naive Bayes: Chi Squared (K-Best)

# %%
df = pd.read_csv('results/dataset-fs-chi-squared.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'var_smoothing': [0.001, 0.10, 0.25, 0.50, 0.75, 1]}
result_NB_chi, ic_NB_chi = Classifier_grid(X, y, k_folds, parameters_in, GaussianNB, dataSet='CHI')
print("Melhor resultado:")
result_NB_chi
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 6
# Parametro: 1 / 6
# {'var_smoothing': 0.001}
# Parametro: 2 / 6
# {'var_smoothing': 0.1}
# Parametro: 3 / 6
# {'var_smoothing': 0.25}
# Parametro: 4 / 6
# {'var_smoothing': 0.5}
# Parametro: 5 / 6
# {'var_smoothing': 0.75}
# Parametro: 6 / 6
# {'var_smoothing': 1}
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 0  GaussianNB      0.741058  ...    0.726894          0.001
#
# [1 rows x 6 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 0         0.673445          0.80867  ...       0.808358          0.001
#
# [1 rows x 9 columns]
# Melhor resultado:
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 0  GaussianNB      0.741058  ...    0.726894          0.001
#
# [1 rows x 6 columns]

# %% [markdown]
# Índice de Confiança para o dataset Chi-Squared

# %%
ic_NB_chi
# Out:
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 0         0.673445          0.80867  ...       0.808358          0.001
#
# [1 rows x 9 columns]

# %% [markdown]
# ### 1.4. Naive Bayes: Recursive Feature

# %%
df = pd.read_csv('results/dataset-fs-recursive-feature.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'var_smoothing': [0.001, 0.10, 0.25, 0.50, 0.75, 1]}
result_NB_rf, ic_NB_rf = Classifier_grid(X, y, k_folds, parameters_in, GaussianNB, dataSet='Recursive')
result_NB_rf
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 6
# Parametro: 1 / 6
# {'var_smoothing': 0.001}
# Parametro: 2 / 6
# {'var_smoothing': 0.1}
# Parametro: 3 / 6
# {'var_smoothing': 0.25}
# Parametro: 4 / 6
# {'var_smoothing': 0.5}
# Parametro: 5 / 6
# {'var_smoothing': 0.75}
# Parametro: 6 / 6
# {'var_smoothing': 1}
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 0  GaussianNB      0.731875  ...    0.715121          0.001
#
# [1 rows x 6 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 0         0.666579         0.797171  ...       0.796879          0.001
#
# [1 rows x 9 columns]
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 0  GaussianNB      0.731875  ...    0.715121          0.001
#
# [1 rows x 6 columns]

# %% [markdown]
# Índice de Confiança para dataset Recursive-Feature

# %%
ic_NB_rf
# Out:
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 0         0.666579         0.797171  ...       0.796879          0.001
#
# [1 rows x 9 columns]

# %% [markdown]
# # 2. SVM

# %% [markdown]
# ##### Parâmetros de execução do SVM
#
# * k_folds:     número de folds para a estratificação do dataset
#
# * list_c:      valores do parâmetro de ajuste de probabilidade
#
# * list_degree: valores do parâmetro degree utilizado no kernel poly
#
# * list_gamma:  valores do parâmetro gamma utilizado no kernel poly
#
# * list_coef:   valores do parâmetro coef utilizado no kernel rbf

# %% [markdown]
# * Função que aplica o SVM para cada Kernel implementado
# * Em cada kernel é testado vários valores de cada parâmetro.
# * Com o resultado de cada parâmetro, verifica qual a melhor acurácia.

# %%
# list_c = [0.001, 0.10, 0.25, 0.50, 0.75, 1]
list_c = [0.001, 0.10]
list_gamma = [0.001, 0.1, 0.5, 1]
list_degree = [1, 2, 3, 4, 5]

list_coef = [0.01]

# %% [markdown]
# ### 2.1. SVM: all features

# %%
df = pd.read_csv('results/dataset-normalizado.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target

list_kernel = ['linear', 'poly', 'rbf', 'sigmoid']

for kernel in list_kernel:
  print(kernel)
  parameters_in = {'C': [0.001, 0.10],
                 'kernel': [kernel],
                 'degree': [1, 2, 3, 4, 5],
                 'gamma' : [0.001, 0.1, 0.5, 1]}
  exec("SVM_{i}_all, SVM_{i}_ic_all = Classifier_grid(X, y, k_folds, parameters_in, svm.SVC, dataSet='All Features')".format(i=kernel))
# Out:
# linear
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC      0.697909       0.754553    0.697909  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20         0.625931         0.769886          0.702986  ...       1  0.001  linear
#
# [1 rows x 12 columns]
# poly
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...      C  degree  gamma  kernel
# 11  SVC       0.71024       0.731985     0.71024  ...  0.001       3    1.0    poly
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 11         0.634177         0.786304          0.664784  ...       3    1.0    poly
#
# [1 rows x 12 columns]
# rbf
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 21  SVC      0.673341        0.70829    0.673341  ...  0.1       1    0.1     rbf
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 21         0.604949         0.741734          0.633665  ...       1    0.1     rbf
#
# [1 rows x 12 columns]
# sigmoid
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma   kernel
# 21  SVC      0.673365       0.687235    0.673365  ...  0.1       1    0.1  sigmoid
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma   kernel
# 21         0.608886         0.737845          0.570872  ...       1    0.1  sigmoid
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Linear
SVM_linear_all
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC      0.697909       0.754553    0.697909  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]

# %%
SVM_linear_ic_all
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20         0.625931         0.769886          0.702986  ...       1  0.001  linear
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Polynomial
SVM_poly_all
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...      C  degree  gamma  kernel
# 11  SVC       0.71024       0.731985     0.71024  ...  0.001       3    1.0    poly
#
# [1 rows x 9 columns]

# %%
SVM_poly_ic_all
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 11         0.634177         0.786304          0.664784  ...       3    1.0    poly
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do Kernel RBF
SVM_rbf_all
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 21  SVC      0.673341        0.70829    0.673341  ...  0.1       1    0.1     rbf
#
# [1 rows x 9 columns]

# %%
SVM_rbf_ic_all
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 21         0.604949         0.741734          0.633665  ...       1    0.1     rbf
#
# [1 rows x 12 columns]

# %% [markdown]
# ### 2.2. SVM: PCA

# %%
df = pd.read_csv('results/dataset-pca.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
list_kernel = ['linear', 'poly', 'rbf', 'sigmoid']

for ker in list_kernel:
  print(ker)
  parameters_in = {'C': [0.001, 0.10],
                 'kernel': [ker],
                 'degree': [1, 2, 3, 4, 5],
                 'gamma' : [0.001, 0.1, 0.5, 1]}
  exec("SVM_{i}_pca, SVM_{i}_ic_pca = Classifier_grid(X, y, k_folds, parameters_in, svm.SVC, dataSet='PCA')".format(i=ker))
# Out:
# linear
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC      0.699495       0.738248    0.699495  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20          0.62453          0.77446          0.678692  ...       1  0.001  linear
#
# [1 rows x 12 columns]
# poly
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 22  SVC      0.700937       0.734984    0.700937  ...  0.1       1    0.5    poly
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 22         0.624257         0.777618          0.673032  ...       1    0.5    poly
#
# [1 rows x 12 columns]
# rbf
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 21  SVC      0.684111        0.70368    0.684111  ...  0.1       1    0.1     rbf
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 21         0.602005         0.766217          0.615024  ...       1    0.1     rbf
#
# [1 rows x 12 columns]
# sigmoid
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma   kernel
# 21  SVC      0.688702       0.715918    0.688702  ...  0.1       1    0.1  sigmoid
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma   kernel
# 21         0.599372         0.778031          0.630559  ...       1    0.1  sigmoid
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Linear
SVM_linear_pca
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC      0.699495       0.738248    0.699495  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]

# %%
SVM_linear_ic_pca
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20          0.62453          0.77446          0.678692  ...       1  0.001  linear
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel poly
SVM_poly_pca
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 22  SVC      0.700937       0.734984    0.700937  ...  0.1       1    0.5    poly
#
# [1 rows x 9 columns]

# %%
SVM_poly_ic_pca
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 22         0.624257         0.777618          0.673032  ...       1    0.5    poly
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel rbf
SVM_rbf_pca
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 21  SVC      0.684111        0.70368    0.684111  ...  0.1       1    0.1     rbf
#
# [1 rows x 9 columns]

# %%
SVM_rbf_ic_pca
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 21         0.602005         0.766217          0.615024  ...       1    0.1     rbf
#
# [1 rows x 12 columns]

# %% [markdown]
# ### 2.3. SVM: Chi Squared (k-Best)

# %%
df = pd.read_csv('results/dataset-fs-chi-squared.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target

list_kernel = ['linear', 'poly', 'rbf', 'sigmoid']

for kernel in list_kernel:
  print(kernel)
  parameters_in = {'C': [0.001, 0.10],
                 'kernel': [kernel],
                 'degree': [1, 2, 3, 4, 5],
                 'gamma' : [0.001, 0.1, 0.5, 1]}
  exec("SVM_{i}_chi, SVM_{i}_ic_chi = Classifier_grid(X, y, k_folds, parameters_in, svm.SVC, dataSet='CHI')".format(i=kernel))
# Out:
# linear
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC       0.70101       0.744777     0.70101  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20         0.612182         0.789837          0.675395  ...       1  0.001  linear
#
# [1 rows x 12 columns]
# poly
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 27  SVC      0.708726        0.74989    0.708726  ...  0.1       2    1.0    poly
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 27         0.630528         0.786924          0.686755  ...       2    1.0    poly
#
# [1 rows x 12 columns]
# rbf
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 21  SVC      0.711803       0.755496    0.711803  ...  0.1       1    0.1     rbf
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 21         0.619454         0.804152           0.68169  ...       1    0.1     rbf
#
# [1 rows x 12 columns]
# sigmoid
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma   kernel
# 21  SVC      0.696394       0.737129    0.696394  ...  0.1       1    0.1  sigmoid
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma   kernel
# 21         0.618939          0.77385          0.669108  ...       1    0.1  sigmoid
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Linear
SVM_linear_chi
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC       0.70101       0.744777     0.70101  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]

# %%
SVM_linear_ic_chi
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20         0.612182         0.789837          0.675395  ...       1  0.001  linear
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Poly
SVM_poly_chi
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 27  SVC      0.708726        0.74989    0.708726  ...  0.1       2    1.0    poly
#
# [1 rows x 9 columns]

# %%
SVM_poly_ic_chi
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 27         0.630528         0.786924          0.686755  ...       2    1.0    poly
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel RBF
SVM_rbf_chi
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 21  SVC      0.711803       0.755496    0.711803  ...  0.1       1    0.1     rbf
#
# [1 rows x 9 columns]

# %%
SVM_rbf_ic_chi
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 21         0.619454         0.804152           0.68169  ...       1    0.1     rbf
#
# [1 rows x 12 columns]

# %% [markdown]
# ### 2.4. SVM: Recursive Feature

# %%
df = pd.read_csv('results/dataset-fs-recursive-feature.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
list_kernel = ['linear', 'poly', 'rbf', 'sigmoid']

for kernel in list_kernel:
  print(kernel)
  parameters_in = {'C': [0.001, 0.10],
                 'kernel': [kernel],
                 'degree': [1, 2, 3, 4, 5],
                 'gamma' : [0.001, 0.1, 0.5, 1]}
  exec("SVM_{i}_rf, SVM_{i}_ic_rf = Classifier_grid(X, y, k_folds, parameters_in, svm.SVC, dataSet='Recursive')".format(i=kernel))
# Out:
# linear
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'linear'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'linear'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'linear'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC      0.719423       0.770335    0.719423  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20         0.628961         0.809885          0.702988  ...       1  0.001  linear
#
# [1 rows x 12 columns]
# poly
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'poly'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'poly'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'poly'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'poly'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'poly'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 23  SVC      0.719423       0.770335    0.719423  ...  0.1       1    1.0    poly
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 23         0.628961         0.809885          0.702988  ...       1    1.0    poly
#
# [1 rows x 12 columns]
# rbf
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'rbf'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'rbf'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'rbf'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'rbf'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'rbf'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 22  SVC      0.703966       0.769364    0.703966  ...  0.1       1    0.5     rbf
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 22         0.608703          0.79923          0.711012  ...       1    0.5     rbf
#
# [1 rows x 12 columns]
# sigmoid
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 40
# Parametro: 1 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 2 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 3 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 4 / 40
# {'C': 0.001, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 5 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 6 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 7 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 8 / 40
# {'C': 0.001, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 9 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 10 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 11 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 12 / 40
# {'C': 0.001, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 13 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 14 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 15 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 16 / 40
# {'C': 0.001, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 17 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 18 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 19 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 20 / 40
# {'C': 0.001, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 21 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 22 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 23 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 24 / 40
# {'C': 0.1, 'degree': 1, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 25 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 26 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 27 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 28 / 40
# {'C': 0.1, 'degree': 2, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 29 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 30 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 31 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 32 / 40
# {'C': 0.1, 'degree': 3, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 33 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 34 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 35 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 36 / 40
# {'C': 0.1, 'degree': 4, 'gamma': 1, 'kernel': 'sigmoid'}
# Parametro: 37 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.001, 'kernel': 'sigmoid'}
# Parametro: 38 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.1, 'kernel': 'sigmoid'}
# Parametro: 39 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 0.5, 'kernel': 'sigmoid'}
# Parametro: 40 / 40
# {'C': 0.1, 'degree': 5, 'gamma': 1, 'kernel': 'sigmoid'}
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma   kernel
# 21  SVC      0.674904       0.774811    0.674904  ...  0.1       1    0.1  sigmoid
#
# [1 rows x 9 columns]
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma   kernel
# 21         0.613049         0.736759          0.736551  ...       1    0.1  sigmoid
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Linear
SVM_linear_rf
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 20  SVC      0.719423       0.770335    0.719423  ...  0.1       1  0.001  linear
#
# [1 rows x 9 columns]

# %%
SVM_linear_ic_rf
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 20         0.628961         0.809885          0.702988  ...       1  0.001  linear
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel Poly
SVM_poly_rf
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 23  SVC      0.719423       0.770335    0.719423  ...  0.1       1    1.0    poly
#
# [1 rows x 9 columns]

# %%
SVM_poly_ic_rf
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 23         0.628961         0.809885          0.702988  ...       1    1.0    poly
#
# [1 rows x 12 columns]

# %%
# Exibe o resultado do kernel RBF
SVM_rbf_rf
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...    C  degree  gamma  kernel
# 22  SVC      0.703966       0.769364    0.703966  ...  0.1       1    0.5     rbf
#
# [1 rows x 9 columns]

# %%
SVM_rbf_ic_rf
# Out:
#     accuracy_ic_inf  accuracy_ic_sup  precision_ic_inf  ...  degree  gamma  kernel
# 22         0.608703          0.79923          0.711012  ...       1    0.5     rbf
#
# [1 rows x 12 columns]

# %% [markdown]
# # 3.Redes Neurais

# %% [markdown]
# ##### Parâmetros de execução das Redes Neurais
#
# * k_folds:     número de folds para a estratificação do dataset
#
# * hidden_layer_sizes:      valores do parâmetro quantidades de neuronios camada oculta
#
# * activation: Função de ativação
#
# * learning_rate:  Taxa de aprendizado pesos
#
# * max_iter:   Número maximo de iterações

# %%
df = pd.read_csv('results/dataset-normalizado.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'activation': ['identity','logistic','tanh','relu'], # {‘identity’, ‘logistic’, ‘tanh’, ‘relu’}, default=’relu’
                 'hidden_layer_sizes': [(56,56)], #default=(100,)
                 'learning_rate_init': [0.001, 0.01], #default=0.001
                 'max_iter':[1000]
                 }
RN_all,RN_all_ic = Classifier_grid(X, y, k_folds, parameters_in,MLPClassifier, dataSet='All Features')
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 8
# Parametro: 1 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 2 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 3 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 4 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 5 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 6 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 7 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 8 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
#    MLPClassifier  accuracy_avg  ...  learning_rate_init  max_iter
# 1  MLPClassifier      0.713317  ...                0.01      1000
#
# [1 rows x 9 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  learning_rate_init  max_iter
# 1         0.630891         0.795744  ...                0.01      1000
#
# [1 rows x 12 columns]

# %%
df = pd.read_csv('results/dataset-pca.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'activation': ['identity','logistic','tanh','relu'], # {‘identity’, ‘logistic’, ‘tanh’, ‘relu’}, default=’relu’
                 'hidden_layer_sizes': [(56,56)], #default=(100,)
                 'learning_rate_init': [0.001, 0.01], #default=0.001
                 'max_iter':[1000]
                 }
RN_pca,RN_pca_ic = Classifier_grid(X, y, k_folds, parameters_in,MLPClassifier, dataSet='PCA')
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 8
# Parametro: 1 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 2 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 3 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 4 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 5 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 6 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 7 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 8 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
#    MLPClassifier  accuracy_avg  ...  learning_rate_init  max_iter
# 0  MLPClassifier      0.697885  ...               0.001      1000
#
# [1 rows x 9 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  learning_rate_init  max_iter
# 0         0.632484         0.763285  ...               0.001      1000
#
# [1 rows x 12 columns]

# %%
df = pd.read_csv('results/dataset-fs-recursive-feature.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'activation': ['identity','logistic','tanh','relu'], # {‘identity’, ‘logistic’, ‘tanh’, ‘relu’}, default=’relu’
                 'hidden_layer_sizes': [(56,56)], #default=(100,)
                 'learning_rate_init': [0.001, 0.01], #default=0.001
                 'max_iter':[1000]
                 }
RN_rf,RN_rf_ic = Classifier_grid(X, y, k_folds, parameters_in,MLPClassifier, dataSet='Recursive')
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 8
# Parametro: 1 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 2 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 3 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 4 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 5 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 6 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 7 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 8 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
#    MLPClassifier  accuracy_avg  ...  learning_rate_init  max_iter
# 1  MLPClassifier      0.736418  ...                0.01      1000
#
# [1 rows x 9 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  learning_rate_init  max_iter
# 1         0.653934         0.818903  ...                0.01      1000
#
# [1 rows x 12 columns]

# %%
df = pd.read_csv('results/dataset-fs-chi-squared.csv', header = 0)
X = df.drop('is_approved', axis=1).to_numpy() # DATASET
y = df['is_approved'].to_numpy() # target
parameters_in = {'activation': ['identity','logistic','tanh','relu'], # {‘identity’, ‘logistic’, ‘tanh’, ‘relu’}, default=’relu’
                 'hidden_layer_sizes': [(56,56)], #default=(100,)
                 'learning_rate_init': [0.001, 0.01], #default=0.001
                 'max_iter':[1000]
                 }
RN_chi,RN_chi_ic = Classifier_grid(X, y, k_folds, parameters_in,MLPClassifier, dataSet='CHI')
# Out:
# k = 10, Dataset: 348 positivas, 301 negativas (53% x 46%)
#
# Fold 0: Pos: 34, Neg: 31, Total: 65, Proporção: 52% x 47%
# Fold 1: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 2: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 3: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 4: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 5: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 6: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 7: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 8: Pos: 35, Neg: 30, Total: 65, Proporção: 53% x 46%
# Fold 9: Pos: 34, Neg: 30, Total: 64, Proporção: 53% x 46%
#
# ---
# Quantidade de parametros: 8
# Parametro: 1 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 2 / 8
# {'activation': 'identity', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 3 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 4 / 8
# {'activation': 'logistic', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 5 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 6 / 8
# {'activation': 'tanh', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
# Parametro: 7 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.001, 'max_iter': 1000}
# Parametro: 8 / 8
# {'activation': 'relu', 'hidden_layer_sizes': (56, 56), 'learning_rate_init': 0.01, 'max_iter': 1000}
#    MLPClassifier  accuracy_avg  ...  learning_rate_init  max_iter
# 0  MLPClassifier      0.725649  ...               0.001      1000
#
# [1 rows x 9 columns]
#    accuracy_ic_inf  accuracy_ic_sup  ...  learning_rate_init  max_iter
# 0         0.642982         0.808316  ...               0.001      1000
#
# [1 rows x 12 columns]

# %% [markdown]
# # Resultados do Naive Bayes

# %% [markdown]
# ##### Imprime os resultados com os respectivos parametros e intervalos de confiança

# %%
R_NB  = pd.concat([result_NB_all,result_NB_pca,result_NB_chi,result_NB_rf])
R_NB
# Out:
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 1  GaussianNB      0.714880  ...    0.700049          0.100
# 3  GaussianNB      0.687188  ...    0.650919          0.500
# 0  GaussianNB      0.741058  ...    0.726894          0.001
# 0  GaussianNB      0.731875  ...    0.715121          0.001
#
# [4 rows x 6 columns]

# %%
R_NB_ic  = pd.concat([ic_NB_all,ic_NB_pca,ic_NB_chi,ic_NB_rf])
R_NB_ic
# Out:
#    accuracy_ic_inf  accuracy_ic_sup  ...  fscore_ic_sup  var_smoothing
# 1         0.647212         0.782547  ...       0.780758          0.100
# 3         0.615426         0.758949  ...       0.753306          0.500
# 0         0.673445         0.808670  ...       0.808358          0.001
# 0         0.666579         0.797171  ...       0.796879          0.001
#
# [4 rows x 9 columns]

# %% [markdown]
# # Resultados do SVM

# %% [markdown]
# Imprime os resultados com os respectivos parametros e intervalos de confiança

# %%
R_SVM  = pd.concat([SVM_linear_all,SVM_linear_pca,SVM_linear_rf,SVM_linear_chi,
                    SVM_poly_all,SVM_poly_pca,SVM_poly_rf,SVM_poly_chi,
                    SVM_rbf_all,SVM_rbf_pca,SVM_rbf_rf,SVM_rbf_chi])
R_SVM
# Out:
#     SVC  accuracy_avg  precision_avg  recall_avg  ...      C  degree  gamma  kernel
# 20  SVC      0.697909       0.754553    0.697909  ...  0.100       1  0.001  linear
# 20  SVC      0.699495       0.738248    0.699495  ...  0.100       1  0.001  linear
# 20  SVC      0.719423       0.770335    0.719423  ...  0.100       1  0.001  linear
# 20  SVC      0.701010       0.744777    0.701010  ...  0.100       1  0.001  linear
# 11  SVC      0.710240       0.731985    0.710240  ...  0.001       3  1.000    poly
# 22  SVC      0.700937       0.734984    0.700937  ...  0.100       1  0.500    poly
# 23  SVC      0.719423       0.770335    0.719423  ...  0.100       1  1.000    poly
# 27  SVC      0.708726       0.749890    0.708726  ...  0.100       2  1.000    poly
# 21  SVC      0.673341       0.708290    0.673341  ...  0.100       1  0.100     rbf
# 21  SVC      0.684111       0.703680    0.684111  ...  0.100       1  0.100     rbf
# 22  SVC      0.703966       0.769364    0.703966  ...  0.100       1  0.500     rbf
# 21  SVC      0.711803       0.755496    0.711803  ...  0.100       1  0.100     rbf
#
# [12 rows x 9 columns]

# %%
R_SVM_ic  = pd.concat([result_NB_all,result_NB_pca,result_NB_chi,result_NB_rf])
R_SVM_ic
# Out:
#    GaussianNB  accuracy_avg  ...  fscore_avg  var_smoothing
# 1  GaussianNB      0.714880  ...    0.700049          0.100
# 3  GaussianNB      0.687188  ...    0.650919          0.500
# 0  GaussianNB      0.741058  ...    0.726894          0.001
# 0  GaussianNB      0.731875  ...    0.715121          0.001
#
# [4 rows x 6 columns]

# %% [markdown]
# # Resultados da Redes Neurais

# %% [markdown]
# Imprime os resultados com os respectivos parametros e intervalos de confiança

# %%
R_RN = pd.concat([RN_all,RN_pca,RN_rf,RN_chi])
R_RN
# Out:
#    MLPClassifier  accuracy_avg  ...  learning_rate_init  max_iter
# 1  MLPClassifier      0.713317  ...               0.010      1000
# 0  MLPClassifier      0.697885  ...               0.001      1000
# 1  MLPClassifier      0.736418  ...               0.010      1000
# 0  MLPClassifier      0.725649  ...               0.001      1000
#
# [4 rows x 9 columns]

# %%
R_RN_ic = pd.concat([RN_all_ic,RN_pca_ic,RN_rf_ic,RN_chi_ic])
R_RN_ic
# Out:
#    accuracy_ic_inf  accuracy_ic_sup  ...  learning_rate_init  max_iter
# 1         0.630891         0.795744  ...               0.010      1000
# 0         0.632484         0.763285  ...               0.001      1000
# 1         0.653934         0.818903  ...               0.010      1000
# 0         0.642982         0.808316  ...               0.001      1000
#
# [4 rows x 12 columns]

# %% [markdown]
# # Gerar Graficos

# %%
""""
df = G.sort_index()
df['Parametros'] = df[['Features','Classificador']].fillna('').apply(lambda x: '\n'.join((x).astype(str)), axis=1)

conf = [df['accuracy_ic_sup'].array , df['accuracy_ic_inf'].array]
means = df['accuracy_avg'].array
ic = [conf[0]-means , means-conf[1]]


g = plt.bar(df['Parametros'].array, df['accuracy_avg'].array, yerr=ic,width=0.9,zorder=2,align='center')
plt.grid()
g[0].set_color('g')
g[4].set_color('g')
g[8].set_color('g')
g[12].set_color('g')
plt.title("Accuracy_avg")
plt.ylabel('Accuracy_avg')
plt.xlabel('Classificador')
plt.yticks(np.arange(0, 1.1, .1))
plt.rcParams["figure.figsize"] = (10,10)
plt.show()
# Out:
#   File "<ipython-input-56-23baba561d96>", line 21
#     plt.show()
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
""""
df = G.sort_index()
df['Parametros'] = df[['Features','Classificador']].fillna('').apply(lambda x: '\n'.join((x).astype(str)), axis=1)
conf = [df['precision_ic_sup'].array , df['precision_ic_inf'].array]
means = df['precision_avg'].array
ic = [conf[0]-means , means-conf[1]]
g = plt.bar(df['Parametros'].array, df['precision_avg'].array, yerr=ic,width=0.9,zorder=2)
plt.grid()
g[0].set_color('g')
g[4].set_color('g')
g[8].set_color('g')
g[12].set_color('g')
plt.title("Precision_avg")
plt.ylabel('Precision_avg')
plt.xlabel('Classificador')
plt.yticks(np.arange(0, 1.1, .1))
plt.rcParams["figure.figsize"] = (10,10)
plt.show()

# %%
""""
df = G.sort_index()
df['Parametros'] = df[['Features','Classificador']].fillna('').apply(lambda x: '\n'.join((x).astype(str)), axis=1)
conf = [df['recall_ic_sup'].array , df['recall_ic_inf'].array]
means = df['recall_avg'].array
ic = [conf[0]-means , means-conf[1]]
g = plt.bar(df['Parametros'].array, df['recall_avg'].array, yerr=ic,width=0.9,zorder=2)
plt.grid()
g[0].set_color('g')
g[4].set_color('g')
g[8].set_color('g')
g[12].set_color('g')
plt.title("Recall_avg")
plt.ylabel('Recall_avg')
plt.xlabel('Classificador')
plt.yticks(np.arange(0, 1.1, .1))
plt.rcParams["figure.figsize"] = (10,10)
plt.show()
